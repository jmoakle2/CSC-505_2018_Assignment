# %%
import numpy as np
import matplotlib.pyplot as plt 

import pandas as pd  
import seaborn as sns 

# %matplotlib inline

# %%
from sklearn.datasets import load_boston

boston_dataset = load_boston()

# boston_dataset is a dictionary
# let's check what it contains
boston_dataset.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
boston = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
boston['MEDV'] = boston_dataset.target
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# **1. Data Understanding and Preprocessing**
#
# Check if any of the feature variables have null values and drop all null values

# %%
boston
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %%
boston = boston.dropna()
boston
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %% [markdown]
# There are no null-values in the boston data-set.

# %% [markdown]
# **1.1. Data Visualization**
#
# Create a histogram of the boston data-set

# %%
# Set the size of the figure
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
sns.distplot(boston['MEDV'],kde = False)
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# D:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# **1.2. Correlation Matrix**
#
# First, compute the pairwise correlation for all the columns.

# %%
boston_corr = boston.corr(method='pearson')
boston_corr
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# Next, use heatmap() to plot the correlation matrix.

# %%
# Draw a very basic heatmap of the boston correlated matrix.
sns.heatmap(boston_corr, annot=True)

# %%
# Draw a heatmap of a diagonalized version of the boston correlated matrix.
mask = np.zeros_like(boston_corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(boston_corr, mask=mask, cmap=cmap, annot=True, vmax=.6, center=0, square=True)

# %% [markdown]
# *Observations:*
# If we consider 0.60 to be the minimum correlation value needed for two variables to be considered in somewhat of a relationship and -0.60 to be the maximum correlation value needed for two variables to be considered in somewhat of an inverse relationship, we can tell that the following variables have some sort of a relation with each other:
#
#     > CRIM has correlation with RAD.
#     > ZN has correlation with DIS.
#     > INDUS has correlation with LSTAT, TAX, RAD, AGE, and NOX.
#     > INDUS has an inverse relation with DIS.
#     > NOX has correlation with TAX, RAD, AGE, and INDUS.
#     > NOX has an inverse relation with DIS.
#     > RM has correlation with MEDV.
#     > RM has an inverse relation with LSTAT.
#     > AGE has correlation with LSTAT, INDUS, and NOX.
#     > AGE has an inverse relation with DIS.
#     > DIS has correlation with ZN.
#     > DIS has an inverse relation with INDUS, NOX, and AGE.
#     > RAD has correlation with TAX, CRIM, INDUS, and NOX.
#     > TAX has correlation with INDUS, NOX, and RAD.
#     > LSTAT has correlation with INDUS and AGE.
#     > LSTAT has an inverse relation with MEDV and RM.
#     > MEDV has correlation with RM.
#     > MEDV has an inverse relation with LSTAT.
#     > LSTAT has an inverse relation with MEDV.
#
# Other important notes about the heatmap and the correlation matrix are:
#
#     > The greatest correlation coefficient of any relation (disregarding an integer's sign) is given from the relation of
#       RAD and TAX.
#     > The only variables that have no relations of any kind are CHAS, PTRATIO, and B.
#     > Variables with three or more relations of any kind are more inclined to be related, somehow, with other variables
#       with three or more relations. These variables are INDUS, TAX, RAD, AGE, AND NOX.

# %% [markdown]
# **Confirmation of Correlation**
#
# Show correlations using MEDV and the INDUS, RM, and LSTAT variables.

# %%
fig, axs = plt.subplots(1, 3, sharey=True)
boston.plot(kind='scatter', x='INDUS', y='MEDV', ax=axs[0], figsize=(16, 8))
boston.plot(kind='scatter', x='RM', y='MEDV', ax=axs[1])
boston.plot(kind='scatter', x='LSTAT', y='MEDV', ax=axs[2])
plt.show()

# %% [markdown]
# **2. Basic Linear Regression**
#
# Prep the data for training.

# %%
boston_X = boston.as_matrix(columns=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT'])
boston_y = boston.as_matrix(columns=['MEDV'])
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %% [markdown]
# **2.1. Create Validation Data**
#
# Split the boston dataset into the training and testing sets using a 80:20 ratio.

# %%
from sklearn.model_selection import train_test_split

XTrain, XTest, yTrain, yTest = train_test_split(boston_X, boston_y, test_size=0.20, random_state=0)

# %% [markdown]
# **2.2. Train the Model**
#
# Use sklearn's LinearRegression to train the model and predict values.

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(XTrain, yTrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# Make predictions based off XTest.

# %% [markdown]
# **2.3. Evaluate the Model**
#
# Use R^2 and RMSE scores for the training and validation data.

# %%
from sklearn.metrics import mean_squared_error, r2_score
print("RMSE for the linear model:", np.sqrt(mean_squared_error(yTest, model.predict(XTest))))
print("R^2 score for the linear model:", r2_score(yTest, model.predict(XTest)))
# Out:
# RMSE for the linear model: 5.783509315085135
# R^2 score for the linear model: 0.5892223849182507

# %% [markdown]
# **2.4. Plotting the Linear Regression Model**
#
# Plot the Linear Regression Model for INDUS, RM, and LSTAT.

# %%
import statsmodels.formula.api as smf

# Create a DataFrame object containing all test set values.
Test_df = pd.DataFrame({'INDUS':[x[2] for x in XTest], 'RM':[x[5] for x in XTest],
                        'LSTAT':[x[12] for x in XTest], 'MEDV':[y[0] for y in yTest]})

# Use the model to make predictions for INDUS.
lm = smf.ols(formula='MEDV ~ INDUS', data=Test_df).fit()
X_new = pd.DataFrame({'INDUS':[Test_df.INDUS.min(), Test_df.INDUS.max()]})
yPred = lm.predict(X_new)
Test_df.plot(kind='scatter', x='INDUS', y='MEDV')
plt.plot(X_new, yPred, color='red', linewidth=2)
plt.show()

# %%
# Use the model to make predictions for RM.
lm = smf.ols(formula='MEDV ~ RM', data=Test_df).fit()
X_new = pd.DataFrame({'RM':[Test_df.RM.min(), Test_df.RM.max()]})
yPred = lm.predict(X_new)
Test_df.plot(kind='scatter', x='RM', y='MEDV')
plt.plot(X_new, yPred, color='red', linewidth=2)
plt.show()

# %%
# Use the model to make predictions for LSTAT.
lm = smf.ols(formula='MEDV ~ LSTAT', data=Test_df).fit()
X_new = pd.DataFrame({'LSTAT':[Test_df.LSTAT.min(), Test_df.LSTAT.max()]})
yPred = lm.predict(X_new)
Test_df.plot(kind='scatter', x='LSTAT', y='MEDV')
plt.plot(X_new, yPred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# **3. Evaluate the Effect of Dimensionality Reduction**
#
# Reduce dimensions by using a test number of components 2.

# %%
# Instantiate PCA, get new X and y, and fit the pca.
from sklearn.decomposition import PCA
X, y = boston_dataset.data, boston_dataset.target
pca = PCA(n_components=2)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %% [markdown]
# **3.1. Transform the original data to the PCA components**

# %%
X_reduced = pca.transform(X)

# %% [markdown]
# Use train_test_split() to create training and testing data.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_reduced, y, test_size=0.20, random_state=0)

# %% [markdown]
# **3.2. Fit the linear regression model and evaluate its performance**

# %%
red_lin_reg_model = LinearRegression()
red_lin_reg_model.fit(X_train, y_train)
y_pred = red_lin_reg_model.predict(X_test)

# %%
# Evaluate the training set.
from sklearn.metrics import explained_variance_score, mean_squared_error, r2_score
print("Explained variance regression score of the training set:",
      explained_variance_score(y_train, red_lin_reg_model.predict(X_train)))
print("RMSE for the reduced training set:", np.sqrt(mean_squared_error(y_train, red_lin_reg_model.predict(X_train))))
print("R^2 score for the reduced training set:", r2_score(y_train, red_lin_reg_model.predict(X_train)))

from sklearn.model_selection import cross_val_score
print("Reduced training score by cross-validation:", cross_val_score(red_lin_reg_model, X_train, y_train, cv=3))
# Out:
# Explained variance regression score of the training set: 0.28655540098868804
# RMSE for the reduced training set: 7.79392887658026
# R^2 score for the reduced training set: 0.28655540098868815
# Reduced training score by cross-validation: [0.40741876 0.25776379 0.19418632]

# %%
# Evaluate the testing set.
print("Explained variance regression score of the testing set:",
      explained_variance_score(y_test, y_pred))
print("RMSE for the reduced testing set:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R^2 score for the reduced testing set:", r2_score(y_test, y_pred))

from sklearn.model_selection import cross_val_score
print("Reduced testing score by cross-validation:", cross_val_score(red_lin_reg_model, X_test, y_test, cv=3))
# Out:
# Explained variance regression score of the testing set: 0.052593867086391466
# RMSE for the reduced testing set: 8.793138490005797
# R^2 score for the reduced testing set: 0.0504633836140983
# Reduced testing score by cross-validation: [0.07249924 0.03391971 0.10668215]

# %% [markdown]
# **4. Evaluate a Random Forest Regressor**
#
# Conduct the same steps as linear regression model but with Random Forest Regressor. Describe the difference between training and validation error.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

rfr_model = RandomForestRegressor(max_depth=2, random_state=0, n_estimators=100)
X_new_train, X_new_test, y_new_train, y_new_test = train_test_split(boston_X, boston_y, test_size=0.20, random_state=0)
rfr_model.fit(X_new_train, y_new_train)
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=2,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %% [markdown]
# Plotting the Random Forest Regression Model.

# %%
# Create a DataFrame object containing all test set values.
New_test_df = pd.DataFrame({'CRIM':[x[0] for x in X_new_test], 'ZN':[x[1] for x in X_new_test],
                            'INDUS':[x[2] for x in X_new_test], 'CHAS':[x[3] for x in X_new_test],
                            'NOX':[x[4] for x in X_new_test], 'RM':[x[5] for x in X_new_test],
                            'AGE':[x[6] for x in X_new_test], 'DIS':[x[7] for x in X_new_test],
                            'RAD':[x[8] for x in X_new_test], 'TAX':[x[9] for x in X_new_test],
                            'PTRATIO':[x[10] for x in X_new_test], 'B':[x[11] for x in X_new_test],
                            'LSTAT':[x[12] for x in X_new_test], 'MEDV':[y[0] for y in y_new_test]})

# Use the model to make predictions for INDUS.
New_test_fit = pd.DataFrame({'CRIM':np.linspace(New_test_df.CRIM.min(), New_test_df.CRIM.max()),
                             'ZN':np.linspace(New_test_df.ZN.min(), New_test_df.ZN.max()),
                             'INDUS':np.linspace(New_test_df.INDUS.min(), New_test_df.INDUS.max()),
                             'CHAS':np.linspace(New_test_df.CHAS.min(), New_test_df.CHAS.max()),
                             'NOX':np.linspace(New_test_df.NOX.min(), New_test_df.NOX.max()),
                             'RM':np.linspace(New_test_df.RM.min(), Test_df.RM.max()),
                             'AGE':np.linspace(New_test_df.AGE.min(), New_test_df.AGE.max()),
                             'DIS':np.linspace(New_test_df.DIS.min(), New_test_df.DIS.max()),
                             'RAD':np.linspace(New_test_df.RAD.min(), New_test_df.RAD.max()),
                             'TAX':np.linspace(New_test_df.TAX.min(), New_test_df.TAX.max()),
                             'PTRATIO':np.linspace(New_test_df.PTRATIO.min(), New_test_df.PTRATIO.max()),
                             'B':np.linspace(New_test_df.B.min(), New_test_df.B.max()),
                             'LSTAT':np.linspace(New_test_df.LSTAT.min(), New_test_df.LSTAT.max())})
y_fit = rfr_model.predict(New_test_fit)
plt.scatter(New_test_df.INDUS, New_test_df.MEDV)
plt.plot(New_test_fit.INDUS, y_fit, color='red')
plt.show()

# %% [markdown]
# **Random Forest Regressor Model Evaluation**

# %%
from sklearn.metrics import explained_variance_score, mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score
print("Explained variance regression score of the training set:",
      explained_variance_score(y_new_train, rfr_model.predict(X_new_train)))
print("R^2 score for the random forest regressor model:", r2_score(y_new_test, rfr_model.predict(X_new_test)))
print("RMSE for the random forest regressor model:", np.sqrt(mean_squared_error(y_new_test, rfr_model.predict(X_new_test))))
print("Training score by cross-validation:", cross_val_score(rfr_model, X_new_train, y_new_train, cv=3))
# Out:
# Explained variance regression score of the training set: 0.7989525402427505
# R^2 score for the random forest regressor model: 0.6436980431610857
# RMSE for the random forest regressor model: 5.386382104909844
# D:\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
print("Explained variance regression score of the testing set:",
      explained_variance_score(y_new_test, rfr_model.predict(X_new_test)))
print("R^2 score for the random forest regressor model:", r2_score(y_new_test, rfr_model.predict(X_new_test)))
print("RMSE for the random forest regressor model:", np.sqrt(mean_squared_error(y_new_test, rfr_model.predict(X_new_test))))

from sklearn.model_selection import cross_val_score
print("Testing score by cross-validation:", cross_val_score(rfr_model, X_new_test, y_new_test, cv=3))
# Out:
# Explained variance regression score of the testing set: 0.6437506979971697
# R^2 score for the random forest regressor model: 0.6436980431610857
# RMSE for the random forest regressor model: 5.386382104909844
# Testing score by cross-validation: [0.61795285 0.64863965 0.4679887 ]
# D:\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# D:\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %% [markdown]
# When evaluating the R^2 score and RMSE on the random forest regressor model's training and testing sets, they appear to be the same values for both sets. As for the cross-validation scores, the training set's scores appeared to be much higher than the testing set's.
